# %%
import pandas as pd
import numpy as np

# %%
import chardet

def read_data(filepath, filetype="csv"):
 
  if filetype not in ["csv", "xlsx"]:
    raise ValueError(f"Unsupported file type: {filetype}")

  try:
    # Open the file in binary mode and read the initial bytes for encoding detection
    with open(filepath, 'rb') as rawdata:
      content = rawdata.read(1024)  # Adjust buffer size as needed

    # Use chardet to detect encoding
    encoding_info = chardet.detect(content)
    encoding = encoding_info['encoding']

    # Read data using the detected encoding
    if filetype == "csv":
      data = pd.read_csv(filepath, encoding=encoding)
    else:
      data = pd.read_excel(filepath)
    return data

  except FileNotFoundError:
    raise FileNotFoundError(f"File not found: {filepath}")

  except UnicodeDecodeError:
    raise UnicodeDecodeError(f"Failed to decode file even with detected encoding: {encoding}")

# %%
def detect_column_types(df):
  

  column_types = {}

  for col in df.columns:
    column_data = df[col]
    
    # Check for numeric types
    if pd.api.types.is_numeric_dtype(column_data):
      column_types[col] = 'numeric'
    elif pd.api.types.is_datetime64_dtype(column_data):
      column_types[col] = 'datetime'
    elif isinstance(column_data.dtype, pd.CategoricalDtype):
      column_types[col] = 'categorical'
    else:
      # Handle mixed types or text data
      unique_values = column_data.unique()
      if len(unique_values) <= 10:
        column_types[col] = 'categorical'  # Consider few unique values as categorical
      else:
        column_types[col] = 'text'

  return column_types

# %%
# Test CSV
try:
  df = read_data("Speaker physical.csv")
  print("CSV read successfully!")
except (ValueError, FileNotFoundError) as e:
  print(f"Error reading CSV: {e}")

# Test Excel
""" try:
  df = read_data("Speaker physical.xlsx", filetype="xlsx")
  print("Excel read successfully!")
except (ValueError, FileNotFoundError) as e:
  print(f"Error reading Excel: {e}")
 """
# Out:
# CSV read successfully!
# ' try:\n  df = read_data("Speaker physical.xlsx", filetype="xlsx")\n  print("Excel read successfully!")\nexcept (ValueError, FileNotFoundError) as e:\n  print(f"Error reading Excel: {e}")\n '

# %%
df.head()
# Out:
#   Unnamed: 0                  Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0        NaN                         NaN        NaN        NaN
# 1         SN                       Name         Sex    Country
# 2          1         Josephine Mebawondu     Female    NIGERIA
# 3          2        ADEGUN, Iyanu Pelumi     Female    NIGERIA
# 4          3  Castro Gbêmêmali HOUNMENOU       Male     Guinea
#
#                                           Unnamed: 4             Unnamed: 5  \
# 0                                                NaN                    NaN
# 1                                        Affliation   Mode of presentation
# 2                  Afe Babalola University Ado-Ekiti               Physical
# 3            FEDERAL UNIVERSITY OF TECHNOLOGY, AKURE               Physical
# 4  Centre de Recherche et de Formation en Infecti...               Physical
#
#     Unnamed: 6    Unnamed: 7                   Unnamed: 8    Unnamed: 9
# 0          NaN           NaN                          NaN           NaN
# 1     Comments  Sponsorship                         Email  Phone number
# 2  Recommended           YES        jpmebawondu@gmail.com   2.34806E+12
# 3  Recommended            NO      iyanupelumi22@gmail.com   2.34814E+12
# 4  Recommended            NO  castro.hounmenou@cerfig.org   2.24628E+11

# %%
null_data = df[df.isnull().any(axis=1)]

# %%
null_data
# Out:
#    Unnamed: 0       Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0         NaN              NaN        NaN        NaN
# 26         25  Aurelle TCHAGNA       Male   Cameroon
#
#                                            Unnamed: 4 Unnamed: 5  \
# 0                                                 NaN        NaN
# 26  College of Technology, University of Buea, Cam...    Virtual
#
#           Unnamed: 6 Unnamed: 7           Unnamed: 8 Unnamed: 9
# 0                NaN        NaN                  NaN        NaN
# 26  Recommended/Good         NO  tkaurelle@gmail.com        NaN

# %%
column_types = detect_column_types(df)
column_types
# Out:
# {'Unnamed: 0': 'text',
#  'Unnamed: 1': 'text',
#  'Unnamed: 2': 'categorical',
#  'Unnamed: 3': 'categorical',
#  'Unnamed: 4': 'text',
#  'Unnamed: 5': 'categorical',
#  'Unnamed: 6': 'categorical',
#  'Unnamed: 7': 'categorical',
#  'Unnamed: 8': 'text',
#  'Unnamed: 9': 'text'}

# %%
data = read_data("Speaker physical.csv")

def wrangle(data, col_missing_threshold=60, row_missing_threshold=60):

  # Handle empty DataFrame
  if data.empty:
      return pd.DataFrame()

  # Calculate missing value percentage for columns
  col_missing_percentage = (data.isnull().sum() / len(data)) * 100
  cols_to_drop = col_missing_percentage[col_missing_percentage > col_missing_threshold].index
  data.drop(columns=cols_to_drop, inplace=True)

  # Calculate missing value percentage for rows
  row_missing_percentage = (data.isnull().sum(axis=1) / len(data.columns)) * 100
  rows_to_drop = row_missing_percentage[row_missing_percentage > row_missing_threshold].index
  data.drop(index=rows_to_drop, inplace=True)


  return data, column_types

# %%
wrangle(data)
# Out:
# (   Unnamed: 0                       Unnamed: 1 Unnamed: 2 Unnamed: 3  \
#  1          SN                            Name         Sex    Country
#  2           1              Josephine Mebawondu     Female    NIGERIA
#  3           2             ADEGUN, Iyanu Pelumi     Female    NIGERIA
#  4           3       Castro Gbêmêmali HOUNMENOU       Male     Guinea
#  5           4  Mubarak Mohammed Al Ezzi Sufyan       Male      Yemen
#  6           5          Agboola Grace Temidayo      Female    NIGERIA
#  7           6          AYEGBUSI  FLORENCE DAMI     Female    NIGERIA
#  8           7                  Nafisah Sumaila     Female      Ghana
#  9           8               Oluyemi E. ADETOYI     Female    Nigeria
#  10          9                    Sola Babalola       Male    Nigeria
#  11         10       Theresa Funmilayo Otokola      Female    Nigeria
#  12         11       Boluwatife Mercy Ogunjirin     Female    Nigeria
#  13         12            Asegunloluwa Babalola    Female     Nigeria
#  14         13               Olusola Favour Joy     Female    Nigeria
#  15         14                Fisayo D. Owoeye      Female    Nigeria
#  16         15               Feyi A. Oluwasanmi       Male    Nigeria
#  17         16                      Dada Joseph       Male    Nigeria
#  18         17                    Samuel Taiwo      Female    Nigeria
#  19         18              Ariane Houetohossou     Female      Benin
#  20         19                      TAHI Souand     Female      Benin
#  21         20    Orounla Bissilimou Rachidatou     Female      Ghana
#  22         21        Ologunagba Grace Feyikemi     Female    Nigeria
#  23         22               Mobolaji Tenibiaje       Male    Nigeria
#  24         23          Afolayan Abimbola Helen     Female    Nigeria
#  25         24                Sadura Akinrinwa      Female    Nigeria
#  26         25                  Aurelle TCHAGNA       Male   Cameroon
#  27         26                  Omoyele Odeniyi     Female    NIGERIA
#
#                                             Unnamed: 4             Unnamed: 5  \
#  1                                         Affliation   Mode of presentation
#  2                   Afe Babalola University Ado-Ekiti               Physical
#  3             FEDERAL UNIVERSITY OF TECHNOLOGY, AKURE               Physical
#  4   Centre de Recherche et de Formation en Infecti...               Physical
#  5          Ministry of Local Administration at Yemen                 Virtual
#  6                   Afe Babalola University Ado-Ekiti               Physical
#  7                   FIRST TECHNICAL UNIVERSITY IBADAN               Physical
#  8                  University for Development Studies               Physical
#  9                                University of Ibadan               Physical
#  10                                Elizade University                Physical
#  11                               Kadosh Mechatronics                Physical
#  12            Federal University of Technology Akure                Physical
#  13                            Anchor University Lagos               Physical
#  14            Smart Systems Research Laboratory, FUTA               Physical
#  15       Wesley University Ondo, Ondo State, Nigeria                Physical
#  16                                  Elfas Consultants               Physical
#  17                                Elizade University                Physical
#  18            Federal University of Technology Akure                Physical
#  19                                          LABEF/UAC               Physical
#  20   Laboratory of Biomathematics and Forest Estim...               Physical
#  21      School of Public Health, University of Ghana                Physical
#  22                        Rufus Giwa Polytechnic, Owo               Physical
#  23  Bamidele Olumilua University of Education, Sci...               Physical
#  24            Federal University of Technology Akure                 Virtual
#  25            Federal University of Technology Akure                Physical
#  26  College of Technology, University of Buea, Cam...                Virtual
#  27            FEDERAL UNIVERSITY OF TECHNOLOGY, AKURE               Physical
#
#            Unnamed: 6    Unnamed: 7                               Unnamed: 8  \
#  1           Comments  Sponsorship                                     Email
#  2        Recommended           YES                    jpmebawondu@gmail.com
#  3        Recommended            NO                  iyanupelumi22@gmail.com
#  4        Recommended            NO              castro.hounmenou@cerfig.org
#  5        Recommended            NO                 mub.sufyan2015@gmail.com
#  6        Recommended           YES             temidayoagboola177@gmail.com
#  7   Recommended/Good           YES                   florahdammmy@gmail.com
#  8   Recommended/Good           YES                  sumyla2nafisa@gmail.com
#  9   Recommended/Good           YES                    yemi.ade.oe@gmail.com
#  10       Recommended            NO                         b_sola@yahoo.com
#  11  Recommended/Good            NO                 otokolatheresa@gmail.com
#  12  Recommended/Good            NO            boluwatifeogunjirin@gmail.com
#  13       Recommended           YES                   asegunloluwa@gmail.com
#  14  Recommended/Good            NO               olusolafavourjoy@gmail.com
#  15  Recommended/Good           YES                 owoeye.fisayo@gmail.com
#  16  Recommended/Good            NO                 oluwasanmifeyi@yahoo.com
#  17       Recommended            NO  babatunde.dada@elizadeuniversity.edu.ng
#  18  Recommended/Good            NO                 Samueltaiwo856@gmail.com
#  19       Recommended           YES                  harianecalmet@gmail.com
#  20       Recommended           YES                     souandtahi@gmail.com
#  21       Recommended           YES                       rachobis@gmail.com
#  22       Recommended            NO                      khemyolog@gmail.com
#  23       Recommended            NO        tenibiaje.mobolaji@bouesti.edu.ng
#  24       Recommended            NO                   ahafolayan@futa.edu.ng
#  25  Recommended/Good            NO                  Spakinrinwa@futa.edu.ng
#  26  Recommended/Good            NO                      tkaurelle@gmail.com
#  27  Recommended/Good            NO                    e.a.odeniyi@gmail.com
#
#                    Unnamed: 9
#  1               Phone number
#  2                2.34806E+12
#  3                2.34814E+12
#  4                2.24628E+11
#  5              92-3379748822
#  6   09076274339  09049347802
#  7                2.34703E+12
#  8                2.33245E+11
#  9                 8059228970
#  10                8034505004
#  11                7083700189
#  12                7061607825
#  13                8030576281
#  14                8051722674
#  15               2.34707E+12
#  16                8067168763
#  17               2.34807E+12
#  18                8032190671
#  19               22966147886
#  20               2.29996E+11
#  21                 2.332E+11
#  22               2.34817E+12
#  23                8064560326
#  24               2.34803E+12
#  25               2.34804E+12
#  26                       NaN
#  27               2.34704E+12  ,
#  {'Unnamed: 0': 'text',
#   'Unnamed: 1': 'text',
#   'Unnamed: 2': 'categorical',
#   'Unnamed: 3': 'categorical',
#   'Unnamed: 4': 'text',
#   'Unnamed: 5': 'categorical',
#   'Unnamed: 6': 'categorical',
#   'Unnamed: 7': 'categorical',
#   'Unnamed: 8': 'text',
#   'Unnamed: 9': 'text'})

# %%
data
# Out:
#    Unnamed: 0                       Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 1          SN                            Name         Sex    Country
# 2           1              Josephine Mebawondu     Female    NIGERIA
# 3           2             ADEGUN, Iyanu Pelumi     Female    NIGERIA
# 4           3       Castro Gbêmêmali HOUNMENOU       Male     Guinea
# 5           4  Mubarak Mohammed Al Ezzi Sufyan       Male      Yemen
# 6           5          Agboola Grace Temidayo      Female    NIGERIA
# 7           6          AYEGBUSI  FLORENCE DAMI     Female    NIGERIA
# 8           7                  Nafisah Sumaila     Female      Ghana
# 9           8               Oluyemi E. ADETOYI     Female    Nigeria
# 10          9                    Sola Babalola       Male    Nigeria
# 11         10       Theresa Funmilayo Otokola      Female    Nigeria
# 12         11       Boluwatife Mercy Ogunjirin     Female    Nigeria
# 13         12            Asegunloluwa Babalola    Female     Nigeria
# 14         13               Olusola Favour Joy     Female    Nigeria
# 15         14                Fisayo D. Owoeye      Female    Nigeria
# 16         15               Feyi A. Oluwasanmi       Male    Nigeria
# 17         16                      Dada Joseph       Male    Nigeria
# 18         17                    Samuel Taiwo      Female    Nigeria
# 19         18              Ariane Houetohossou     Female      Benin
# 20         19                      TAHI Souand     Female      Benin
# 21         20    Orounla Bissilimou Rachidatou     Female      Ghana
# 22         21        Ologunagba Grace Feyikemi     Female    Nigeria
# 23         22               Mobolaji Tenibiaje       Male    Nigeria
# 24         23          Afolayan Abimbola Helen     Female    Nigeria
# 25         24                Sadura Akinrinwa      Female    Nigeria
# 26         25                  Aurelle TCHAGNA       Male   Cameroon
# 27         26                  Omoyele Odeniyi     Female    NIGERIA
#
#                                            Unnamed: 4             Unnamed: 5  \
# 1                                         Affliation   Mode of presentation
# 2                   Afe Babalola University Ado-Ekiti               Physical
# 3             FEDERAL UNIVERSITY OF TECHNOLOGY, AKURE               Physical
# 4   Centre de Recherche et de Formation en Infecti...               Physical
# 5          Ministry of Local Administration at Yemen                 Virtual
# 6                   Afe Babalola University Ado-Ekiti               Physical
# 7                   FIRST TECHNICAL UNIVERSITY IBADAN               Physical
# 8                  University for Development Studies               Physical
# 9                                University of Ibadan               Physical
# 10                                Elizade University                Physical
# 11                               Kadosh Mechatronics                Physical
# 12            Federal University of Technology Akure                Physical
# 13                            Anchor University Lagos               Physical
# 14            Smart Systems Research Laboratory, FUTA               Physical
# 15       Wesley University Ondo, Ondo State, Nigeria                Physical
# 16                                  Elfas Consultants               Physical
# 17                                Elizade University                Physical
# 18            Federal University of Technology Akure                Physical
# 19                                          LABEF/UAC               Physical
# 20   Laboratory of Biomathematics and Forest Estim...               Physical
# 21      School of Public Health, University of Ghana                Physical
# 22                        Rufus Giwa Polytechnic, Owo               Physical
# 23  Bamidele Olumilua University of Education, Sci...               Physical
# 24            Federal University of Technology Akure                 Virtual
# 25            Federal University of Technology Akure                Physical
# 26  College of Technology, University of Buea, Cam...                Virtual
# 27            FEDERAL UNIVERSITY OF TECHNOLOGY, AKURE               Physical
#
#           Unnamed: 6    Unnamed: 7                               Unnamed: 8  \
# 1           Comments  Sponsorship                                     Email
# 2        Recommended           YES                    jpmebawondu@gmail.com
# 3        Recommended            NO                  iyanupelumi22@gmail.com
# 4        Recommended            NO              castro.hounmenou@cerfig.org
# 5        Recommended            NO                 mub.sufyan2015@gmail.com
# 6        Recommended           YES             temidayoagboola177@gmail.com
# 7   Recommended/Good           YES                   florahdammmy@gmail.com
# 8   Recommended/Good           YES                  sumyla2nafisa@gmail.com
# 9   Recommended/Good           YES                    yemi.ade.oe@gmail.com
# 10       Recommended            NO                         b_sola@yahoo.com
# 11  Recommended/Good            NO                 otokolatheresa@gmail.com
# 12  Recommended/Good            NO            boluwatifeogunjirin@gmail.com
# 13       Recommended           YES                   asegunloluwa@gmail.com
# 14  Recommended/Good            NO               olusolafavourjoy@gmail.com
# 15  Recommended/Good           YES                 owoeye.fisayo@gmail.com
# 16  Recommended/Good            NO                 oluwasanmifeyi@yahoo.com
# 17       Recommended            NO  babatunde.dada@elizadeuniversity.edu.ng
# 18  Recommended/Good            NO                 Samueltaiwo856@gmail.com
# 19       Recommended           YES                  harianecalmet@gmail.com
# 20       Recommended           YES                     souandtahi@gmail.com
# 21       Recommended           YES                       rachobis@gmail.com
# 22       Recommended            NO                      khemyolog@gmail.com
# 23       Recommended            NO        tenibiaje.mobolaji@bouesti.edu.ng
# 24       Recommended            NO                   ahafolayan@futa.edu.ng
# 25  Recommended/Good            NO                  Spakinrinwa@futa.edu.ng
# 26  Recommended/Good            NO                      tkaurelle@gmail.com
# 27  Recommended/Good            NO                    e.a.odeniyi@gmail.com
#
#                   Unnamed: 9
# 1               Phone number
# 2                2.34806E+12
# 3                2.34814E+12
# 4                2.24628E+11
# 5              92-3379748822
# 6   09076274339  09049347802
# 7                2.34703E+12
# 8                2.33245E+11
# 9                 8059228970
# 10                8034505004
# 11                7083700189
# 12                7061607825
# 13                8030576281
# 14                8051722674
# 15               2.34707E+12
# 16                8067168763
# 17               2.34807E+12
# 18                8032190671
# 19               22966147886
# 20               2.29996E+11
# 21                 2.332E+11
# 22               2.34817E+12
# 23                8064560326
# 24               2.34803E+12
# 25               2.34804E+12
# 26                       NaN
# 27               2.34704E+12
